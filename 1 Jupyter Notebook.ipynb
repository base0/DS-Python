# %% [markdown]
# # Jupyter Notebook
#
# วรเศรษฐ สุวรรณิก
#
# 1. Run a Cell
# 1. MD
#     - heading
#     - bullet, number
#     - latex math
#     - insert a picture
# 1. Interactive
# 1. API Key

# %% [markdown]
# # Run a cell
#
# กด shift+enter หรือ control+enter หรือเลือกจากเมนู

# %%
1+2
# Out:
# 3

# %% [markdown]
# **exercise**
#
# 1. shift+enter หรือ control+enter ต่างกันอย่างไร
# 1. ลูปค้าง แก้อย่างไร

# %% [markdown]
# # MD
#
# - heading `#`
# - bullet `-`
# - number `1.`
# - bold `**`
# - link `[text](url)`
# - image `![](worasait.png)`
# - latex math `$x_1$`
#
# **exercise** เขียนข้อความที่มี
#
# 1. heading 2 ระดับ
# 1. bullet 2 ระดับ
# 1. link ไปยังเว็บเกษตรศาสตร์
# 1. upload รูปแล้วนำรูปมาแสดง

# %% [markdown]
# # Interactive
#
# ใช้สไลด์เดอร์ช่วยในการปรับค่าพารามิเตอร์
#
# ตอนนี้ยังใช้กับ JupyterLab ใน CC Labs ไม่ได้

# %%
from ipywidgets import interact

def f(n): print(n+1)

interact(f, n=(1,10,2))
# Out:
# 6
# <function __main__.f(n)>

# %% [markdown]
# **exercise**

# %% [markdown]
# # API Key
#
# ## `import` เจ้าเก่า
#
# ใช้การ import ไฟล์
#
# ## OS environment
#
# ดูโค้ด

# %%
# %env api_key=NOKSG5OHD5JIJF2CIOGGPNGO3DQT0OWQB1ZQYQYBCXSLMF5O
# Out:
# env: api_key=NOKSG5OHD5JIJF2CIOGGPNGO3DQT0OWQB1ZQYQYBCXSLMF5O

# %%
# !echo "$api_key"
# Out:
# NOKSG5OHD5JIJF2CIOGGPNGO3DQT0OWQB1ZQYQYBCXSLMF5O

# %%
import os
os.environ.get('api_key', None)
# Out:
# 'NOKSG5OHD5JIJF2CIOGGPNGO3DQT0OWQB1ZQYQYBCXSLMF5O'

# %% [markdown]
# **exercise** `import`
#
# สร้างไฟล์ชื่อ myconfig.py ในไฟล์ประกาศสตริง api_key = 'asdfasdf' รันโค้ดต่อไปนี้ (อาจจะต้อง reload jupyterlab)

# %%
import myconfig

myconfig.api_key
